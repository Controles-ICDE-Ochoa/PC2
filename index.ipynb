# %%
"PC2"
# Out:
# 'PC2'

# %%
"PROCEDIMIENTO QUE SE HIZO"
# Out:
# 'PROCEDIMIENTO QUE SE HIZO'

# %%
import pandas as pd
link= "https://github.com/Controles-ICDE-Ochoa/PC2/raw/main/Data/HDI.csv"
data = pd.read_csv(link, encoding='ISO-8859-1')
data
# Out:
#          Back Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                               NaN         NaN                       NaN
# ...

# %%
data.drop(index=[0, 1, 2], inplace=True)
data
# Out:
#          Back Table 1. Human Development Index and its components   \
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                          Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 3    Human Development Index (HDI)          NaN  Life expectancy at birth
# ...

# %%
nuevos_titulos=list(data.iloc[0])
data.columns = nuevos_titulos
data.drop(index=3,inplace=True)
data
# Out:
#           NaN                                                NaN  \
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   NaN Life expectancy at birth  NaN  \
# 4                            Value  NaN                  (years)  NaN
# ...

# %%
data_nan=data.dropna(axis=1, how='all')
data_nan
# Out:
#           NaN                                                NaN  \
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  NaN  \
# 4                            Value                  (years)  NaN
# ...

# %%
data_nan.columns.values[0] = 'Rank'
data_nan.columns.values[1] = 'Country'
data_cleaned = data_nan.loc[:, data_nan.columns.notna()].copy()
data_cleaned
# Out:
#          Rank                                            Country  \
# 4    HDI rank                                            Country
# 5         NaN                                                NaN
# 6         NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7           1                                        Switzerland
# 8           2                                             Norway
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 4                            Value                  (years)
# 5                             2021                     2021
# ...

# %%
data_cleaned.reset_index(drop=True, inplace=True) 
data_cleaned.drop(index=[0, 1, 2], inplace=True)
data_cleaned
# Out:
#     Rank                                            Country  \
# 3      1                                        Switzerland
# 4      2                                             Norway
# 5      3                                            Iceland
# 6      4                             Hong Kong, China (SAR)
# 7      5                                          Australia
# ..   ...                                                ...
# 267  NaN                          Column 2: UNDESA (2022a).
# 268  NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269  NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270  NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271  NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 3                            0.962                     84.0
# 4                            0.961                     83.2
# 5                            0.959                     82.7
# ...

# %%
num_nan = data_cleaned.isna().sum()
num_nan
# Out:
# Rank                                      78
# Country                                   10
# Human Development Index (HDI)             59
# Life expectancy at birth                  59
# Expected years of schooling               59
# Mean years of schooling                   59
# Gross national income (GNI) per capita    59
# GNI per capita rank minus HDI rank        59
# HDI rank                                  59
# dtype: int64

# %%
data_cleaned1 = data_cleaned.dropna(subset=['Rank'])
data_cleaned1
# Out:
#     Rank                   Country Human Development Index (HDI)   \
# 3      1               Switzerland                          0.962
# 4      2                    Norway                          0.961
# 5      3                   Iceland                          0.959
# 6      4    Hong Kong, China (SAR)                          0.952
# 7      5                 Australia                          0.951
# ..   ...                       ...                            ...
# 192  187                   Burundi                          0.426
# 193  188  Central African Republic                          0.404
# 194  189                     Niger                          0.400
# 195  190                      Chad                          0.394
# 196  191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# 3                       84.0                        16.5
# ...

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 3 to 196
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Rank                                    191 non-null    object
#  1   Country                                 191 non-null    object
#  2   Human Development Index (HDI)           191 non-null    object
#  3   Life expectancy at birth                191 non-null    object
#  4   Expected years of schooling             191 non-null    object
#  5   Mean years of schooling                 191 non-null    object
#  6   Gross national income (GNI) per capita  191 non-null    object
#  7   GNI per capita rank minus HDI rank      191 non-null    object
#  8   HDI rank                                191 non-null    object
# dtypes: object(9)
# memory usage: 14.9+ KB

# %%
num_nan = data_cleaned1.isna().sum()
num_nan
# Out:
# Rank                                      0
# Country                                   0
# Human Development Index (HDI)             0
# Life expectancy at birth                  0
# Expected years of schooling               0
# Mean years of schooling                   0
# Gross national income (GNI) per capita    0
# GNI per capita rank minus HDI rank        0
# HDI rank                                  0
# dtype: int64

# %%
data_cleaned2 = data_cleaned1.replace(',', '.', regex=True)
data_cleaned2.iloc[:, 2:] = data_cleaned2.iloc[:, 2:].astype(float)
data_cleaned2
# Out:
#     Rank                   Country Human Development Index (HDI)   \
# 3      1               Switzerland                          0.962
# 4      2                    Norway                          0.961
# 5      3                   Iceland                          0.959
# 6      4    Hong Kong. China (SAR)                          0.952
# 7      5                 Australia                          0.951
# ..   ...                       ...                            ...
# 192  187                   Burundi                          0.426
# 193  188  Central African Republic                          0.404
# 194  189                     Niger                            0.4
# 195  190                      Chad                          0.394
# 196  191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# 3                       84.0                        16.5
# ...

# %%
"VERSIÓN FINAL"
# Out:
# 'VERSIÓN FINAL'

# %%
import pandas as pd
link= "https://github.com/Controles-ICDE-Ochoa/PC2/raw/main/Data/HDI.csv"
data = pd.read_csv(link, encoding='ISO-8859-1')
data.drop(index=[0, 1, 2], inplace=True)
nuevos_titulos=list(data.iloc[0])
data.columns = nuevos_titulos
data.drop(index=3,inplace=True)
data_nan=data.dropna(axis=1, how='all')
data_nan.columns.values[0] = 'Rank'
data_nan.columns.values[1] = 'Country'
data_cleaned = data_nan.loc[:, data_nan.columns.notna()].copy()
data_cleaned.reset_index(drop=True, inplace=True) 
data_cleaned.drop(index=[0, 1, 2], inplace=True)
data_cleaned1 = data_cleaned.dropna(subset=['Rank'])
data_cleaned2 = data_cleaned1.replace(',', '.', regex=True)
data_cleaned2.iloc[:, 2:] = data_cleaned2.iloc[:, 2:].astype(float)
data_cleaned2
# Out:
#     Rank                   Country Human Development Index (HDI)   \
# 3      1               Switzerland                          0.962
# 4      2                    Norway                          0.961
# 5      3                   Iceland                          0.959
# 6      4    Hong Kong. China (SAR)                          0.952
# 7      5                 Australia                          0.951
# ..   ...                       ...                            ...
# 192  187                   Burundi                          0.426
# 193  188  Central African Republic                          0.404
# 194  189                     Niger                            0.4
# 195  190                      Chad                          0.394
# 196  191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# 3                       84.0                        16.5
# ...
